# %% [markdown]
# *import libraries*

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. **Data Loading and exploration and cleaning**
#  ↪ Load the csv file with the seeborn.   because this library provide **Iris** dataset without need of download
#
#
#  ↪ creating the dataframe and understanding the data present in the dataset using pandas
#
#  ↪ Dealing with the missing data, outliers and the incorrect records

# %%
iris_df = sns.load_dataset('iris')

# %% [markdown]
#  - viewing the data

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df=iris_df
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# - let's see the exact column names that we have in this dataset

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
#  - Let's have a look on the shape of dataset

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
#  *` Not enough, let's have a look on the columns and their data types using detailed info function`*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # **Observations**
# ---
# 1. There are 150 rows and 5 columns in the dataset
# 2. The columns are of different data types
# 3. The columns in the datasets are:
#    - `'sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'`
# 4. There are some missing values in the dataset which we will read in details and deal later on in the notebook.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Observations:
# ---
# - We have only 4 columns as numeric data type, rest all are object data type (according to python),but we can see ,according to our needs.
# ---
# - Let's check the null values

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Observations:
# ---
# - we have not  null values in dataset
# ---
#
# - So let's create the scatter plot to analyze the relationships between variables
# - create a scatter plot of that column "sepal_length", and "sepal_width"
# - Use **seaborn** for better visuals and hue/style support

# %%
sns.scatterplot(data=df, x="sepal_length", y="sepal_width", hue="species", style="species")

plt.title("Sepal Length vs Sepal Width")
plt.show()

# %% [markdown]
# ## Observations
# ---
# ### Key Relationships:
# - **Setose** is clearly separable from other two species based on **sepal_length** and **sepal_width**
# - **Versicolor** and **Virginica** shows some **overlap**, making them harder to distinguish using just these two features.
# ---
# - Now let's create the scatter plot to analyze the relationship between  species using that columns **petal_length** and **petal_width**

# %%
sns.scatterplot(data=df, x="petal_length", y="petal_width", hue="species", style="species")

plt.title("Sepal Length vs Sepal Width")
plt.show()

# %% [markdown]
# ## Observations
# ---
# - There is a **strong correalation** between **petal_length** and **petal_width** across all species
# - Each species shows **distinct grouping** especially:
#    - **Setosa**: Perfectly separable
#    - **Versicolor** and **Virginica**: partially overlapping
# ---
# - Now we move on the next step to examine the data distribution
# - Let's create the **Histogram** to examine the distribution of data

# %%
for col in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
    sns.histplot(data=df, x=col, kde=True, bins=20)
    plt.title(f"Distribution of {col.replace('_', ' ').title()}")
    plt.xlabel(col.replace('_', ' ').title())
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# ## Observations
# ---
# ### **1.Distribution of sepal length:**
# - **Distribution Shape:** The distribution of sepal length is roughly normal, peaking between 5.5 and 6.0, with fewer occurrences at the extremes.
#
# - **Frequency:** The highest frequency of sepal lengths occurs between 5.0 and 6.5, indicating that many samples have sepal lengths in this range.
#
# - **Outliers:** There are fewer instances of sepal lengths below 5.0 and above 7.0, indicating potential outliers or less common measurements in those ranges.
#
# - **Kernel Density Estimate (KDE):** The blue line indicates a smoothed estimate of the distribution, reinforcing the notion of a central tendency around 5.5 to 6.0.
# ---
# ### **2.Distribution of sepal width:**
# - **Bimodal Distribution:** There are two distinct peaks, one around 2.5 and another around 3.5, suggesting the presence of two different groups within the data.
#
# - **Frequency:** The highest frequency occurs around 3.0, indicating that many samples have sepal widths in this range.
#
# - **Lower Frequencies at Extremes:** There are fewer instances of sepal widths below 2.0 and above 4.0, indicating less common measurements in those areas.
#
# - **Kernel Density Estimate (KDE):** The blue line reinforces the bimodal nature and highlights the two peaks in the distribution.
# ---
# ### **3.Distribution of petal length:**
# - **Bimodal Distribution:** There are two notable peaks, one around 1.5 and another around 5.0, indicating two distinct groups in the data.
#
# - **High Frequency at Low Values:** A significant number of samples have petal lengths near 1.0 to 2.0, suggesting these lengths are very common.
#
# - **Lower Frequencies in Mid-range:** There are fewer occurrences of petal lengths between 2.5 and 4.5, showing a dip in frequency in this range.
#
# - **Kernel Density Estimate (KDE):** The blue line highlights the bimodal nature of the distribution, with fluctuations indicating variability in the mid-range lengths.
# ---
# ### **4.Distribution of petal width:**
# - **Right-Skewed Distribution:** The distribution is heavily skewed to the right, with a peak around 0.2 to 0.5.
#
# - **High Frequency at Low Values:** There is a significant number of samples with petal widths between 0.0 and 0.5, indicating that these widths are very common.
#
# - **Decreasing Frequency:** As petal width increases, the frequency decreases, with fewer instances in the higher ranges (1.0 to 2.5).
#
# - **Kernel Density Estimate (KDE):** The blue line shows a general decline in density as petal width increases, reinforcing the right-skewed nature of the distribution.
# ---
# - Now we need to create a box plot to analyze or check the outlier

# %%
sns.boxplot(data=df)
plt.title("Box Plots for All Features in Iris Dataset")
plt.show()

# %% [markdown]
# ## Observation
# - **Sepal Length:** The median is around 5.0, with a range extending from approximately 4.0 to 7.0. There are a few outliers above 7.0.
#
# - **Sepal Width:** The median is around 3.0, with a narrower range (about 2.0 to 4.0). There are a few outliers below 2.0.
#
# - **Petal Length:** This feature shows a higher median, around 4.5, with a range from about 1.0 to 7.0. There are noticeable outliers, particularly in the higher range.
#
# - **Petal Width:** The median is around 1.5, with a range from 0.0 to about 2.5, and it has several outliers at lower values.
# ---
# - There are have some outliers in the data
# - we need to remove the outliers, so let's remove

# %%
def remove_outliers_iqr(data):
    numeric_cols = data.select_dtypes(include='number').columns
    for col in numeric_cols:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    return data

# Apply function
df_cleaned = remove_outliers_iqr(df)

# Print before and after
print("Original shape:", df.shape)
print("Shape after removing outliers:", df_cleaned.shape)

df = df_cleaned

# create box plot
sns.boxplot(data=df)
plt.title("Box Plots for All Features in Iris Dataset")
plt.show()
# Out:
# Original shape: (146, 5)
# Shape after removing outliers: (146, 5)

# %% [markdown]
# ## Observations
# - There are not have any outlier , our data is perfectly fine now
